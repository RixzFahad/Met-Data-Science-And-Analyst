# %% [markdown]
# <a href="https://colab.research.google.com/github/RixzFahad/Met-Data-Science-And-Analyst/blob/main/Collection_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Python Collection Test- Tuple|Set|List

# %%
# Question1--
a = "Candy"
print(a[-3:])
print(a[::-1])
# Out:
# ndy
# ydnaC

# %%
#Question2--

def add(a, b):
    return a + b
print(add(2, 3))
# Out:
# 5

# %%
#Question3--
i = 10
while i < 10:
  print(i)
  # never change the i value :- It's Run a infinite Loop.

# %%
# Question4--
li = [1,2,3]
li[1:2] = [9,8]
print(li)
# Out:
# [1, 9, 8, 3]

# %%
#Question5--
s = "Datascience"
print(s[-4:], s[::2])
# Out:
# ence Dtsine

# %%
#Question6--
i = 1
while i <= 5:
    print(i)
    i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ***Practice_Question***

# %%
lst = [1, 2, 3]
lst[1:2] = [9, 8]
print(lst)
# Out:
# [1, 9, 8, 3]

# %%
p = "python"
print(p[1:4])
# Out:
# yth

# %%
li= [10,20,30,40]
print(li.pop())
# Out:
# 40

# %%
print(type({}))
# Out:
# <class 'dict'>

# %%
li1 = [1,2,3,4,5]
li1.append([5,6])
print(li1)
print(len(li1))
# Out:
# [1, 2, 3, 4, 5, [5, 6]]
# 6

# %%
print(bool(""))
# Out:
# False

# %%
for i in range(2, 10, 3):
    print(i, end=" ")
# Out:
# 2 5 8

# %%
x = 5
if x > 3:
    print("A")
elif x > 1:
    print("B")
else:
    print("C")
# Out:
# A

# %%
li2 = [1,2,3]
li3 = li2 * 2
print(li3)
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
print(len("Data\nScience"))
# Out:
# 12

# %%
s = "Python"
print(s[-1])
# Out:
# n

# %%
d = {1: "A", 2: "B"}
print(d.get(3))
# Out:
# None

# %%
print(5 == 5 and 3 > 5)
# Out:
# False

# %%
def test():
    pass

print(test())
# Out:
# None

# %%
print(type(5))
# Out:
# <class 'int'>

# %%
s = "Hello"
print(s[::-2])
# Out:
# olH

# %%
x = [1, 2]
y = x
y.append(3)
print(x)
# Out:
# [1, 2, 3]
