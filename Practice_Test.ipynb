# %% [markdown]
# <a href="https://colab.research.google.com/github/RixzFahad/Met-Data-Science-And-Analyst/blob/main/Practice_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python Practice:-

# %%
# Even Odd Number
x = int(input("enter the number"))
if x % 2 == 0:
    print("Even Number")
else:
    print("odd Numbers")
# Out:
# enter the number1000
# Even Number

# %%
x = 5
if x> 10:
  print("A")
elif x > 3:
  print("B")
else:
  print("C")
# Out:
# B

# %%
x = -1
if x:
    print("True")
else:
    print("False")
# Out:
# True

# %%
x = 10
y = 20
print(x if x > y else y)
# Out:
# 20

# %%
x = 3
if x > 5:
    if x < 10:
        print("Hello")
else:
    print("Hi")
# Out:
# Hi

# %%
x = 0
if x > 0:
    print("Positive")
elif x < 0:
    print("Negative")
else:
    print("Zero")
# Out:
# Zero

# %%
x = 7
if x > 5:
    if x > 10:
        print("Big")
    else:
        print("Medium")
# Out:
# Medium

# %%
a = 5
b = 3
c = 8
if a > b and a > c:
    print("A")
elif b > c:
    print("B")
else:
    print("C")
# Out:
# C

# %%
x = 4
if not x % 2 == 0:
    print("Odd")
else:
    print("Even")
# Out:
# Even

# %%
x = 1
if x == 1 or x == 2:
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %%
x = 6
print("Pass" if x >= 5 else "Fail")
# Out:
# Pass

# %%
x = 10
y = 10
if x is y:
    print("Same")
else:
    print("Different")
# Out:
# Same

# %%
x = ""
if x:
    print("Filled")
else:
    print("Empty")
# Out:
# Empty

# %%
x = 5
if x > 2:
    if x > 10:
        print("High")
    else:
        print("Low")
# Out:
# Low

# %%
x = 9
if x < 5:
    print("Small")
elif x < 10:
    print("Medium")
else:
    print("Large")
# Out:
# Medium

# %%
for i in range(3):
    print(i)
# Out:
# 0
# 1
# 2

# %%
for i in range(1, 6, 2):
    print(i)
# Out:
# 1
# 3
# 5

# %%
for i in range(5):
    if i == 3:
        break
    print(i)
# Out:
# 0
# 1
# 2

# %%
for i in range(5):
    if i == 2:
        continue
    print(i)
# Out:
# 0
# 1
# 3
# 4

# %%
i = 0
while i < 3:
    print(i)
    i += 1
# Out:
# 0
# 1
# 2

# %%
i = 5
while i > 0:
    print(i)
    i -= 2
# Out:
# 5
# 3
# 1

# %%
i = 0
while i < 5:
    if i == 3:
        break
    i += 1
    print(i)
# Out:
# 1
# 2
# 3

# %%
i = 0
while i < 5:
    i += 1
    if i % 2 == 0:
        continue
    print(i)
# Out:
# 1
# 3
# 5

# %%
for i in range(3):
    for j in range(2):
        print(i, j)
# Out:
# 0 0
# 0 1
# 1 0
# 1 1
# 2 0
# 2 1

# %%
i = 0
while i < 3:
    print(i)
    i += 1
else:
    print("Done")
# Out:
# 0
# 1
# 2
# Done

# %%
for i in range(3):
    print(i)
else:
    print("End")
# Out:
# 0
# 1
# 2
# End

# %%
i = 0
while i < 5:
    if i == 4:
        break
    print(i)
    i += 1
else:
    print("Done")
# Out:
# 0
# 1
# 2
# 3

# %%
for i in range(1, 4):
    print(i * i)
# Out:
# 1
# 4
# 9

# %%
i = 1
while i <= 3:
    print(i)
    i += 1
# Out:
# 1
# 2
# 3

# %%
for i in range(5, 2, -1):
    print(i)
# Out:
# 5
# 4
# 3

# %% [markdown]
# Today i have a test where i gotn 17 out of 30 . So here i cheeck them i practice them again where i was stuck
