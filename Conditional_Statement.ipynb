# %% [markdown]
# <a href="https://colab.research.google.com/github/RixzFahad/Met-Data-Science-And-Analyst/blob/main/Conditional_Statement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 15-12-2025
# ## Conditional Statements

# %%
Marks = int(input("Enter the Student Marks: "))

if Marks >= 40:
    print("You are Pass")
else:
    print("You are Fail")
# Out:
# Enter the Student Marks: 12
# You are Fail

# %%
Palindrome = input("Enter the string: ").lower()
if Palindrome == Palindrome[::-1]:
  print("Word Is palindrome")
else:
  print("Not Palindrome")
# Out:
# Enter the string: MADAM
# Word Is palindrome

# %% [markdown]
# Even Or Odd Program

# %%
Even = int(input("Enter Your Number"))
if Even % 2 ==0:
  print("Even Number")
else:
  print("Odd Number")
# Out:
# Enter Your Number33
# Odd Number

# %%
Numbers = int(input("Enter your number: "))

if Numbers > 0:
    print("Positive Number")
elif Numbers == 0:
    print("Neutral Number")
else:
    print("Negative Number")
# Out:
# Enter your number: 99
# Positive Number

# %%
print(not(10==10))
# Out:
# False

# %%
a = 50
b = 45
c= 85
d = 100
if b<d and c>a and d>a:
  print("All conditions are true")
else:
  print("not True")
# Out:
# All conditions are true

# %% [markdown]
# # Teirnery Operator

# %%
age = int(input("Enter Your Age"))
if age >= 18:
  print("eligible")
else:
  print("not Eligible")
check  = "eligible"  if age >= 18 else "not Eligible"
print(check)


1
# Out:
# Enter Your Age11
# not Eligible
# not Eligible
# 1

# %%
age = int(input("Enter Your Age"))
# Out:
# Enter Your Age12
