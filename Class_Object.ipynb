# %% [markdown]
# <a href="https://colab.research.google.com/github/RixzFahad/Met-Data-Science-And-Analyst/blob/main/Class_Object.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***What Is A Class?***

# %% [markdown]
# **A Class Is A BluePrint for creating a object**
#
# *   Where Each Object have there owwn identity,
# *   Attribute's
# *   And Method of interaction's

# %% [markdown]
# # ***What Is Attribute And How Many Attribute We Have??***

# %% [markdown]
# **An Attribute Is A Variable That Belongs To A Class Or An Object.**
# It Is Used To Store Data/State OF An Object.
# We Have Two Attribute In Python.
#
# *   *Instance Attribute*
# *   *Class Attribute*
#
#
# ***These are nothing the data that we are defining in class and object***

# %% [markdown]
# # *Class Attribute :-*
# **These Are Comman Properties Wwhich Everyone Can See It..**

# %% [markdown]
# # *Object Attribute:-*
# **These Are Umique Properties Only Access By A Specific Objecct.**

# %% [markdown]
# # ***What Are Method's--?***

# %% [markdown]
# **A Method Is A Function That Define Inside a class and is Used to define the behaviour of an object's.**
# **Methods are nothing but functions created inside the class**

# %% [markdown]
# # ***What Is A Self--?***

# %% [markdown]
# **Self is a refrence for the current object class.
# It allows an object to access its own attributes and methods.**
# ***Self is a pointer or referencer where it is used to access the particular data or information***

# %%
class Customer:
    bank_name = "PNB"
    IFSC = "PUNB66"
    BRANCH = "Sohawal"
    amount = 0

# %%
customer1 = Bank("Rixz", 50000, 123456, "India")
print(customer1.welcome_wish())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-940533272.py in <cell line: 0>()
# ----> 1 customer1 = Bank("Rixz", 50000, 123456, "India")
#       2 print(customer1.welcome_wish())
#
# TypeError: Bank() takes no arguments

# %%
class Bank:
    bank_name = "ABC Bank"
    BRANCH = "Delhi"

    def __init__(self, name, balance, accountnumber, address):
        self.name = name
        self.balance = balance
        self.accountnumber = accountnumber
        self.address = address

    # Method to welcome a customer
    def welcome_wish(self):
     return f"Hello {self.name}! Welcome to {self.bank_name}, {self.BRANCH}"

# %%
    # Method to check balance
    def check_balance(self):
        return f"Hello {self.name}! Your current balance is {self.balance}/-"

# %%
print(customer1.balance)
# Out:
# 50000

# %%
def deposit(self, amount):
    self.balance = self.balance + amount
    return f"""Your transaction is successful!
Your account has been credited with {amount}/-
Your updated balance is {self.balance}/-."""

# %%
print(customer1.balance)
# Out:
# 50000

# %%
class Customer:
    Bank_Name = "HFC BANK"
    IFSC = "HFC000567"
    BRANCH = "AMEERPET"
    STATE = "TG"

    # how can we create object attributes?
    """
    Before creating the object attributes we need to initialize
    the object attributes inside the class
    """

    def __init__(self, Name, Balance, account_number, address):
        self.Name = Name
        self.Balance = Balance
        self.account_number = account_number
        self.address = address

    # create a method to welcome a customer into bank
    def welcome_wish(self):
        return f"Hello {self.Name}! Welcome to {self.Bank_Name}, {self.BRANCH}, {self.STATE}"

    # create a method to check the balance
    def check_balance(self):
        return f"Hello {self.Name}! Your current balance is {self.Balance}/-"

    # create a method to deposit the amount
    def deposit(self, amount):
        self.Balance = self.Balance + amount
        return f"""Your transaction is successful
Your account has been credited with {amount}/-
Your updated balance is {self.Balance}/-."""

    # create a method to withdraw the amount
    def withdraw(self, amount):
        if amount <= self.Balance:
            self.Balance = self.Balance - amount
            return f"""Your transaction is successful
Your account has been debited with {amount}/-
Your updated balance is {self.Balance}/-."""
        else:
            return "Insufficient funds, please check your balance"

# %%
c1 = Customer("Candy", 15000, 6345736, "Ameerpet, Hyderabad")
c2 = Customer("Rix", 10000, 3476387, "Hyderabad")

# %%
print(c1.IFSC)
print(c2.BRANCH)
# Out:
# HFC000567
# AMEERPET

# %%
print(c1.Balance)
print(c2.account_number)
# Out:
# 15000
# 3476387

# %%
print(c1.welcome_wish())
print(c1.check_balance())
print(c1.deposit(10000))
print(c2.withdraw(25000))
# Out:
# Hello Candy! Welcome to HFC BANK, AMEERPET, TG
# Hello Candy! Your current balance is 15000/-
# Your transaction is successful
# Your account has been credited with 10000/-
# Your updated balance is 25000/-.
# Insufficient funds, please check your balance
