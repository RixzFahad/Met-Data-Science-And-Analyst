# %% [markdown]
# <a href="https://colab.research.google.com/github/RixzFahad/Met-Data-Science-And-Analyst/blob/main/SQL_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ==================================================
# **SQL + Python + Pandas Certification -- MASTER STRUCTURED SHEET**
# ==================================================
#
# --------------------------------------------------
# Q1 -- Tests: Pandas drop_duplicates
# Question: What does df.drop_duplicates(subset=['id'], keep='last') do?
# - Removes all duplicate rows
# - Keeps first occurrence
# - Keeps last occurrence  <-- CORRECT
# - Drops rows where id is null
# Why: keep='last' keeps final duplicate entry.
#
# --------------------------------------------------
# Q2 -- Tests: Pandas filtering + mean
# Question: Output of s=[10,20,30,40]; print(s[s>20].mean())
# - 20
# - 25
# - 35  <-- CORRECT
# - 30
# Why: values 30 & 40 → mean 35.
#
# --------------------------------------------------
# Q3 -- Tests: SQL INSERT
# Question: Which SQL command adds a new record?
# - SELECT
# - DELETE
# - INSERT  <-- CORRECT
# - NONE
# Why: INSERT adds rows.
#
# --------------------------------------------------
# Q4 -- Tests: SQL Aggregates
# Question: Aggregate functions return?
# - Single value  <-- CORRECT
# - Twice
# - NULL
# - Infinite
# Why: summarized output.
#
# --------------------------------------------------
# Q5 -- Tests: SQL math functions
# Question: SQUARE vs POWER?
# - square vs any exponent  <-- CORRECT
# - same
# - sqrt vs square
# - reverse
# Why: POWER(x,y) flexible.
#
# --------------------------------------------------
# Q6 -- Tests: Python list copy
# - [1,2,3,4]
# - [4]
# - [1,2,3]  <-- CORRECT
# - Error
# Why: copy creates new list.
#
# --------------------------------------------------
# Q7 -- Tests: Python references
# - [1,2,3]
# - [4]
# - [1,2,3,4]  <-- CORRECT
# - Error
# Why: same memory reference.
#
# --------------------------------------------------
# Q8 -- Tests: HAVING clause
# - Works like WHERE  <-- CORRECT
# - No effect
# - Error
# - Aggregate only
# Why: filters rows without GROUP BY.
#
# --------------------------------------------------
# Q9 -- Tests: DISTINCT
# - SELECT UNIQUE
# - DISTINCT  <-- CORRECT
# - Both
# - None
# Why: DISTINCT valid SQL.
#
# --------------------------------------------------
# Q10 -- Tests: TRUNCATE
# - Removes all rows  <-- CORRECT
# - Deletes specific
# - Changes structure
# - Creates table
# Why: clears table.
#
# --------------------------------------------------
# Q11 -- Tests: Aggregates
# - AVG
# - FIRST
# - LAST
# - All of the above  <-- CORRECT
# Why: exam considers all aggregates.
#
# --------------------------------------------------
# Q12 -- Tests: Remove duplicates
# - DUPLICATE
# - DISTINCT  <-- CORRECT
# - REMOVE
# - DROP
# Why: DISTINCT keyword.
#
# --------------------------------------------------
# Q13 -- Tests: WHERE vs HAVING
# - WHERE before grouping  <-- CORRECT
# - reverse
# - same
# - HAVING no aggregates
# Why: execution order.
#
# --------------------------------------------------
# Q14 -- Tests: SQL datatype validity
# - Numeric
# - Decimal
# - Character
# - None  <-- CORRECT
# Why: all valid.
#
# --------------------------------------------------
# Q15 -- Tests: Large text datatype
# - TEXT  <-- CORRECT
# - VARCHAR
# - CHAR
# - BLOB
# Why: long content.
#
# --------------------------------------------------
# Q16 -- Tests: Python loop else
# - always
# - only break
# - no break  <-- CORRECT
# - false cond
# Why: executes if loop completes.
#
# --------------------------------------------------
# Q17 -- Tests: Parent-child join
# - FROM
# - TO
# - WHERE  <-- CORRECT
# - IN
# Why: join condition.
#
# --------------------------------------------------
# Q18 -- Tests: RIGHT JOIN
# - include NULL left  <-- CORRECT
# - exclude
# - duplicate
# - replace
# Why: preserves right table rows.
#
# --------------------------------------------------
# Q19 -- Tests: Python loop logic
# - 1 3
# - 0 2 4  <-- CORRECT
# - 2 4
# - all
# Why: even numbers.
#
# --------------------------------------------------
# Q20 -- Tests: SELECT TOP
# - rows  <-- CORRECT
# - columns
# - tables
# - none
# Why: limits rows.
#
# --------------------------------------------------
# Q21 -- Tests: continue keyword
# - 0 1 2
# - 0 2  <-- CORRECT
# - 1 2
# - 0 1
# Why: skips 1.
#
# --------------------------------------------------
# Q22 -- Tests: TRUNCATE vs DELETE
# - TRUNCATE  <-- CORRECT
# - DROP
# - DELETE
# - ALTER
# Why: clears data + space.
#
# --------------------------------------------------
# Q23 -- Tests: ORDER BY
# - filter
# - sort  <-- CORRECT
# - group
# - join
# Why: sorts results.
#
# --------------------------------------------------
# Q24 -- Tests: DB design
# - integrity
# - scalability
# - redundancy  <-- CORRECT
# - efficiency
# Why: redundancy bad design.
#
# --------------------------------------------------
# Q25 -- Tests: normalization
# - increase redundancy
# - speed
# - reduce redundancy  <-- CORRECT
# - security
# Why: remove duplication.
#
# --------------------------------------------------
# Q26 -- Tests: BLOB
# - Binary large object  <-- CORRECT
# - big large
# - binary language
# - none
# Why: binary data.
#
# --------------------------------------------------
# Q27 -- Tests: SQL datetime
# - DATE
# - NOW  <-- CORRECT
# - TIME
# - DATETIME
# Why: current timestamp.
#
# --------------------------------------------------
# Q28 -- Tests: LEFT JOIN
# - left only
# - right only
# - all left + matched right  <-- CORRECT
# - matched only
# Why: preserves left.
#
# --------------------------------------------------
# Q29 -- Tests: WHERE clause
# - GROUP
# - ORDER
# - WHERE  <-- CORRECT
# - HAVING
# Why: row filter.
#
# --------------------------------------------------
# Q30 -- Tests: Primary key
# - Primary key  <-- CORRECT
# - Secondary
# - Foreign
# - Index
# Why: unique identifier.
#
# --------------------------------------------------
# Q31 -- Tests: JOIN condition
# - eteam-team1
# - eteam-team2
# - eteam-goal
# - game JOIN goal ON matchid  <-- CORRECT
# Why: match relationship.
#
# --------------------------------------------------
# Q32 -- Tests: Aggregate set
# - COUNT MAX AVG SUM  <-- CORRECT
# - AVG MAX SUM SELECT
# - UNION SUM AVG MAX
# - SELECT combos
# Why: valid aggregates.
#
# --------------------------------------------------
# Q33 -- Tests: DB terminology
# - Field
# - Attribute
# - Record  <-- CORRECT
# - Column
# Why: row = record.
#
# --------------------------------------------------
# Q34 -- Tests: *args
# - keyword args
# - fixed args
# - variable positional args  <-- CORRECT
# - single arg
# Why: flexible parameters.
#
# --------------------------------------------------
# Q35 -- Tests: DDL commands
# - CREATE
# - ALTER
# - DROP
# - SELECT  <-- CORRECT
# Why: SELECT not DDL.
#
# --------------------------------------------------
# Q36 -- Tests: COUNT
# - COUNT(*)  <-- CORRECT
# - TOTALROWS
# - SUM
# - ROWCOUNT
# Why: row count.
#
# --------------------------------------------------
# Q37 -- Tests: SQL column selection
# - partial
# - partial
# - full dataset fields  <-- CORRECT
# - wrong mix
# Why: required join columns.
#
# --------------------------------------------------
# Q38 -- Tests: DROP vs TRUNCATE
# - drop table vs delete data  <-- CORRECT
# - reverse
# - same
# - modify
# Why: structure vs data.
#
# --------------------------------------------------
# Q39 -- Tests: DROP TABLE
# - delete table  <-- CORRECT
# - create
# - check
# - none
# Why: removes table.
#
# --------------------------------------------------
# Q40 -- Tests: INNER JOIN
# - either table
# - all rows
# - matching rows both tables  <-- CORRECT
# - non-match
# Why: intersection.
#
# --------------------------------------------------
# Q41 -- Tests: SELECT clause rules
# - WHERE
# - GROUP
# - ORDER
# - None  <-- CORRECT
# Why: only SELECT mandatory.
#
# --------------------------------------------------
# Q42 -- Tests: GROUP BY
# - whole table
# - aggregate per group  <-- CORRECT
# - filter
# - sort
# Why: grouped calculation.
#
# --------------------------------------------------
# Q43 -- Tests: Sorting keyword
# - SORT
# - ARRANGE
# - ORDER BY  <-- CORRECT
# - GROUP
# Why: SQL syntax.
#
# --------------------------------------------------
# Q44 -- Tests: UPDATE
# - add rows
# - modify rows  <-- CORRECT
# - delete rows
# - none
# Why: changes values.
#
# --------------------------------------------------
# Q45 -- Tests: DROP vs TRUNCATE
# - drop table vs delete data  <-- CORRECT
# - reverse
# - same
# - modify
# Why: structure vs data.
#
# --------------------------------------------------
# Q46 -- Tests: Database model
# - hierarchical
# - network
# - relational  <-- CORRECT
# - object
# Why: tables model.
#
# --------------------------------------------------
# Q47 -- Tests: CHAR vs VARCHAR
# - fixed vs variable  <-- CORRECT
# - reverse
# - same
# - numeric only
# Why: storage length.
#
# --------------------------------------------------
# Q48 -- Tests: Pandas filtering
# - wrong syntax
# - df[(cond)&(cond)]  <-- CORRECT
# - wrong between
# - invalid
# Why: parentheses needed.
#
# --------------------------------------------------
# Q49 -- Tests: Python pass
# - skip 2
# - 0 1 2 3 4  <-- CORRECT
# - partial
# - error
# Why: pass does nothing.
#
# --------------------------------------------------
# Q50 -- Tests: Pandas transform
# - reduced series
# - dataframe
# - aligned series  <-- CORRECT
# - error
# Why: same length output.
#
# ==================================================
# **END OF MASTER STRUCTURED CERTIFICATION SHEET**
# ==================================================
